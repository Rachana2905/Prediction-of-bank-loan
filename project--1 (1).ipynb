# %%
#importing all packages  
import pandas
import numpy
import seaborn
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score,accuracy_score
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.metrics import classification_report,confusion_matrix
from sklearn .ensemble import RandomForestClassifier

# %%
#to neglect the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#reading the data
bank_data= pandas.read_csv('C:/Users/Dell/Downloads/bank_data_3.csv')

# %%
bank_data
# Out:
#        age            job   marital            education  default  housing  \
# 0       56      housemaid   married             basic.4y       no       no
# 1       57       services   married          high.school  unknown       no
# 2       37       services   married          high.school       no      yes
# 3       40         admin.   married             basic.6y       no       no
# 4       56       services   married          high.school       no       no
# 5       45       services   married             basic.9y  unknown       no
# 6       59         admin.   married  professional.course       no       no
# 7       41    blue-collar   married              unknown  unknown       no
# 8       24     technician    single  professional.course       no      yes
# 9       25       services    single          high.school       no      yes
# 10      41    blue-collar   married              unknown  unknown       no
# ...

# %%
#usefull data
bank_data=bank_data[['age','job','education','housing','loan','month','day_of_week','duration','pdays','branchwise','cons.conf.idx','y']]

# %%
bank_data
# Out:
#        age            job            education  housing     loan month  \
# 0       56      housemaid             basic.4y       no       no   may
# 1       57       services          high.school       no       no   may
# 2       37       services          high.school      yes       no   may
# 3       40         admin.             basic.6y       no       no   may
# 4       56       services          high.school       no      yes   may
# 5       45       services             basic.9y       no       no   may
# 6       59         admin.  professional.course       no       no   may
# 7       41    blue-collar              unknown       no       no   may
# 8       24     technician  professional.course      yes       no   may
# 9       25       services          high.school      yes       no   may
# 10      41    blue-collar              unknown       no       no   may
# 11      25       services          high.school      yes       no   may
# ...

# %%
#seperaing dependent and independent variables
bank_data_x=bank_data[['age','job','education','housing','month','day_of_week','duration','pdays','branchwise','cons.conf.idx','y']]
bank_data_y=bank_data[['loan']]

# %%
#splitting the data
x_train,x_test,y_train,y_test=train_test_split(bank_data_x,bank_data_y,test_size=0.20)

# %%
x_train.head()
# Out:
#        age          job          education housing month day_of_week  \
# 8591    57  blue-collar           basic.9y     yes   jun         wed
# 24954   49  blue-collar           basic.4y      no   nov         tue
# 39477   85    housemaid           basic.4y      no   apr         tue
# 12427   26       admin.  university.degree     yes   jul         mon
# 14931   44       admin.  university.degree      no   jul         wed
#
#        duration  pdays   branchwise  cons.conf.idx   y
# 8591        367    999  nonexistent          -41.8  no
# 24954        34    999      failure          -42.0  no
# 39477       166    999  nonexistent          -34.6  no
# 12427       118    999  nonexistent          -42.7  no
# 14931       191    999  nonexistent          -42.7  no

# %%
#converting catogorical to numerical
age_scaler=StandardScaler()
age_scaler.fit(pandas.DataFrame(x_train['age']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
#transforming the data
x_train[['age']]=age_scaler.transform(x_train[['age']])

# %%
x_train.head()
# Out:
#             age          job          education housing month day_of_week  \
# 8591   1.628822  blue-collar           basic.9y     yes   jun         wed
# 24954  0.860477  blue-collar           basic.4y      no   nov         tue
# 39477  4.318032    housemaid           basic.4y      no   apr         tue
# 12427 -1.348516       admin.  university.degree     yes   jul         mon
# 14931  0.380261       admin.  university.degree      no   jul         wed
#
#        duration  pdays   branchwise  cons.conf.idx   y
# 8591        367    999  nonexistent          -41.8  no
# 24954        34    999      failure          -42.0  no
# 39477       166    999  nonexistent          -34.6  no
# 12427       118    999  nonexistent          -42.7  no
# 14931       191    999  nonexistent          -42.7  no

# %%
#converting catogorical to numerical
duration_scaler=StandardScaler()
duration_scaler.fit(pandas.DataFrame(x_train['duration']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['duration']]=duration_scaler.transform(x_train[['duration']])

# %%
x_train.head()
# Out:
#             age          job          education housing month day_of_week  \
# 8591   1.628822  blue-collar           basic.9y     yes   jun         wed
# 24954  0.860477  blue-collar           basic.4y      no   nov         tue
# 39477  4.318032    housemaid           basic.4y      no   apr         tue
# 12427 -1.348516       admin.  university.degree     yes   jul         mon
# 14931  0.380261       admin.  university.degree      no   jul         wed
#
#        duration  pdays   branchwise  cons.conf.idx   y
# 8591   0.412619    999  nonexistent          -41.8  no
# 24954 -0.863631    999      failure          -42.0  no
# 39477 -0.357730    999  nonexistent          -34.6  no
# 12427 -0.541694    999  nonexistent          -42.7  no
# 14931 -0.261916    999  nonexistent          -42.7  no

# %%
pdays_scaler=StandardScaler()
pdays_scaler.fit(pandas.DataFrame(x_train['pdays']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['pdays']]=pdays_scaler.transform(x_train[['pdays']])

# %%
x_train.head()
# Out:
#             age          job          education housing month day_of_week  \
# 8591   1.628822  blue-collar           basic.9y     yes   jun         wed
# 24954  0.860477  blue-collar           basic.4y      no   nov         tue
# 39477  4.318032    housemaid           basic.4y      no   apr         tue
# 12427 -1.348516       admin.  university.degree     yes   jul         mon
# 14931  0.380261       admin.  university.degree      no   jul         wed
#
#        duration     pdays   branchwise  cons.conf.idx   y
# 8591   0.412619  0.194661  nonexistent          -41.8  no
# 24954 -0.863631  0.194661      failure          -42.0  no
# 39477 -0.357730  0.194661  nonexistent          -34.6  no
# 12427 -0.541694  0.194661  nonexistent          -42.7  no
# 14931 -0.261916  0.194661  nonexistent          -42.7  no

# %%
#coverting numerical to binary language
cons_conf_idx_scaler=StandardScaler()
cons_conf_idx_scaler.fit(pandas.DataFrame(x_train['cons.conf.idx']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['cons.conf.idx']]=cons_conf_idx_scaler.transform(x_train[['cons.conf.idx']])

# %%
x_train.head()
# Out:
#             age          job          education housing month day_of_week  \
# 8591   1.628822  blue-collar           basic.9y     yes   jun         wed
# 24954  0.860477  blue-collar           basic.4y      no   nov         tue
# 39477  4.318032    housemaid           basic.4y      no   apr         tue
# 12427 -1.348516       admin.  university.degree     yes   jul         mon
# 14931  0.380261       admin.  university.degree      no   jul         wed
#
#        duration     pdays   branchwise  cons.conf.idx   y
# 8591   0.412619  0.194661  nonexistent      -0.283170  no
# 24954 -0.863631  0.194661      failure      -0.326341  no
# 39477 -0.357730  0.194661  nonexistent       1.270978  no
# 12427 -0.541694  0.194661  nonexistent      -0.477439  no
# 14931 -0.261916  0.194661  nonexistent      -0.477439  no

# %%
job_encoder=preprocessing.LabelEncoder()
job_encoder.fit(pandas.DataFrame(x_train['job']))
# Out:
# LabelEncoder()

# %%
x_train[['job']]=job_encoder.transform(x_train[['job']])

# %%
x_train.head()
# Out:
#             age  job          education housing month day_of_week  duration  \
# 8591   1.628822    1           basic.9y     yes   jun         wed  0.412619
# 24954  0.860477    1           basic.4y      no   nov         tue -0.863631
# 39477  4.318032    3           basic.4y      no   apr         tue -0.357730
# 12427 -1.348516    0  university.degree     yes   jul         mon -0.541694
# 14931  0.380261    0  university.degree      no   jul         wed -0.261916
#
#           pdays   branchwise  cons.conf.idx   y
# 8591   0.194661  nonexistent      -0.283170  no
# 24954  0.194661      failure      -0.326341  no
# 39477  0.194661  nonexistent       1.270978  no
# 12427  0.194661  nonexistent      -0.477439  no
# 14931  0.194661  nonexistent      -0.477439  no

# %%
job_scaler=StandardScaler()
job_scaler.fit(pandas.DataFrame(x_train['job']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['job']]=job_scaler.transform(x_train[['job']])

# %%
x_train.head()
# Out:
#             age       job          education housing month day_of_week  \
# 8591   1.628822 -0.754524           basic.9y     yes   jun         wed
# 24954  0.860477 -0.754524           basic.4y      no   nov         tue
# 39477  4.318032 -0.197733           basic.4y      no   apr         tue
# 12427 -1.348516 -1.032919  university.degree     yes   jul         mon
# 14931  0.380261 -1.032919  university.degree      no   jul         wed
#
#        duration     pdays   branchwise  cons.conf.idx   y
# 8591   0.412619  0.194661  nonexistent      -0.283170  no
# 24954 -0.863631  0.194661      failure      -0.326341  no
# 39477 -0.357730  0.194661  nonexistent       1.270978  no
# 12427 -0.541694  0.194661  nonexistent      -0.477439  no
# 14931 -0.261916  0.194661  nonexistent      -0.477439  no

# %%
education_encoder=preprocessing.LabelEncoder()
education_encoder.fit(pandas.DataFrame(x_train['education']))
# Out:
# LabelEncoder()

# %%
x_train[['education']]=education_encoder.transform(x_train[['education']])

# %%
x_train.head()
# Out:
#             age       job  education housing month day_of_week  duration  \
# 8591   1.628822 -0.754524          2     yes   jun         wed  0.412619
# 24954  0.860477 -0.754524          0      no   nov         tue -0.863631
# 39477  4.318032 -0.197733          0      no   apr         tue -0.357730
# 12427 -1.348516 -1.032919          6     yes   jul         mon -0.541694
# 14931  0.380261 -1.032919          6      no   jul         wed -0.261916
#
#           pdays   branchwise  cons.conf.idx   y
# 8591   0.194661  nonexistent      -0.283170  no
# 24954  0.194661      failure      -0.326341  no
# 39477  0.194661  nonexistent       1.270978  no
# 12427  0.194661  nonexistent      -0.477439  no
# 14931  0.194661  nonexistent      -0.477439  no

# %%
education_scaler=StandardScaler()
education_scaler.fit(pandas.DataFrame(x_train['education']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['education']]=education_scaler.transform(x_train[['education']])

# %%
x_train.head()
# Out:
#             age       job  education housing month day_of_week  duration  \
# 8591   1.628822 -0.754524  -0.815072     yes   jun         wed  0.412619
# 24954  0.860477 -0.754524  -1.750565      no   nov         tue -0.863631
# 39477  4.318032 -0.197733  -1.750565      no   apr         tue -0.357730
# 12427 -1.348516 -1.032919   1.055915     yes   jul         mon -0.541694
# 14931  0.380261 -1.032919   1.055915      no   jul         wed -0.261916
#
#           pdays   branchwise  cons.conf.idx   y
# 8591   0.194661  nonexistent      -0.283170  no
# 24954  0.194661      failure      -0.326341  no
# 39477  0.194661  nonexistent       1.270978  no
# 12427  0.194661  nonexistent      -0.477439  no
# 14931  0.194661  nonexistent      -0.477439  no

# %%
housing_encoder=preprocessing.LabelEncoder()
housing_encoder.fit(pandas.DataFrame(x_train['housing']))
# Out:
# LabelEncoder()

# %%
x_train[['housing']]=housing_encoder.transform(x_train[['housing']])

# %%
x_train.head()
# Out:
#             age       job  education  housing month day_of_week  duration  \
# 8591   1.628822 -0.754524  -0.815072        2   jun         wed  0.412619
# 24954  0.860477 -0.754524  -1.750565        0   nov         tue -0.863631
# 39477  4.318032 -0.197733  -1.750565        0   apr         tue -0.357730
# 12427 -1.348516 -1.032919   1.055915        2   jul         mon -0.541694
# 14931  0.380261 -1.032919   1.055915        0   jul         wed -0.261916
#
#           pdays   branchwise  cons.conf.idx   y
# 8591   0.194661  nonexistent      -0.283170  no
# 24954  0.194661      failure      -0.326341  no
# 39477  0.194661  nonexistent       1.270978  no
# 12427  0.194661  nonexistent      -0.477439  no
# 14931  0.194661  nonexistent      -0.477439  no

# %%
housing_scaler=StandardScaler()
housing_scaler.fit(pandas.DataFrame(x_train['housing']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['housing']]=housing_scaler.transform(x_train[['housing']])

# %%
x_train.head()
# Out:
#             age       job  education   housing month day_of_week  duration  \
# 8591   1.628822 -0.754524  -0.815072  0.940119   jun         wed  0.412619
# 24954  0.860477 -0.754524  -1.750565 -1.089425   nov         tue -0.863631
# 39477  4.318032 -0.197733  -1.750565 -1.089425   apr         tue -0.357730
# 12427 -1.348516 -1.032919   1.055915  0.940119   jul         mon -0.541694
# 14931  0.380261 -1.032919   1.055915 -1.089425   jul         wed -0.261916
#
#           pdays   branchwise  cons.conf.idx   y
# 8591   0.194661  nonexistent      -0.283170  no
# 24954  0.194661      failure      -0.326341  no
# 39477  0.194661  nonexistent       1.270978  no
# 12427  0.194661  nonexistent      -0.477439  no
# 14931  0.194661  nonexistent      -0.477439  no

# %%
month_encoder=preprocessing.LabelEncoder()
month_encoder.fit(pandas.DataFrame(x_train['month']))
# Out:
# LabelEncoder()

# %%
x_train[['month']]=month_encoder.transform(x_train[['month']])

# %%
x_train.head()
# Out:
#             age       job  education   housing  month day_of_week  duration  \
# 8591   1.628822 -0.754524  -0.815072  0.940119      4         wed  0.412619
# 24954  0.860477 -0.754524  -1.750565 -1.089425      7         tue -0.863631
# 39477  4.318032 -0.197733  -1.750565 -1.089425      0         tue -0.357730
# 12427 -1.348516 -1.032919   1.055915  0.940119      3         mon -0.541694
# 14931  0.380261 -1.032919   1.055915 -1.089425      3         wed -0.261916
#
#           pdays   branchwise  cons.conf.idx   y
# 8591   0.194661  nonexistent      -0.283170  no
# 24954  0.194661      failure      -0.326341  no
# 39477  0.194661  nonexistent       1.270978  no
# 12427  0.194661  nonexistent      -0.477439  no
# 14931  0.194661  nonexistent      -0.477439  no

# %%
month_scaler=StandardScaler()
month_scaler.fit(pandas.DataFrame(x_train['month']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['month']]=month_scaler.transform(x_train[['month']])

# %%
x_train.head()
# Out:
#             age       job  education   housing     month day_of_week  \
# 8591   1.628822 -0.754524  -0.815072  0.940119 -0.098683         wed
# 24954  0.860477 -0.754524  -1.750565 -1.089425  1.195407         tue
# 39477  4.318032 -0.197733  -1.750565 -1.089425 -1.824138         tue
# 12427 -1.348516 -1.032919   1.055915  0.940119 -0.530047         mon
# 14931  0.380261 -1.032919   1.055915 -1.089425 -0.530047         wed
#
#        duration     pdays   branchwise  cons.conf.idx   y
# 8591   0.412619  0.194661  nonexistent      -0.283170  no
# 24954 -0.863631  0.194661      failure      -0.326341  no
# 39477 -0.357730  0.194661  nonexistent       1.270978  no
# 12427 -0.541694  0.194661  nonexistent      -0.477439  no
# 14931 -0.261916  0.194661  nonexistent      -0.477439  no

# %%
day_encoder=preprocessing.LabelEncoder()
day_encoder.fit(pandas.DataFrame(x_train['day_of_week']))
# Out:
# LabelEncoder()

# %%
x_train[['day_of_week']]=day_encoder.transform(x_train[['day_of_week']])

# %%
x_train.head()
# Out:
#             age       job  education   housing     month  day_of_week  \
# 8591   1.628822 -0.754524  -0.815072  0.940119 -0.098683            4
# 24954  0.860477 -0.754524  -1.750565 -1.089425  1.195407            3
# 39477  4.318032 -0.197733  -1.750565 -1.089425 -1.824138            3
# 12427 -1.348516 -1.032919   1.055915  0.940119 -0.530047            1
# 14931  0.380261 -1.032919   1.055915 -1.089425 -0.530047            4
#
#        duration     pdays   branchwise  cons.conf.idx   y
# 8591   0.412619  0.194661  nonexistent      -0.283170  no
# 24954 -0.863631  0.194661      failure      -0.326341  no
# 39477 -0.357730  0.194661  nonexistent       1.270978  no
# 12427 -0.541694  0.194661  nonexistent      -0.477439  no
# 14931 -0.261916  0.194661  nonexistent      -0.477439  no

# %%
day_scaler=StandardScaler()
day_scaler.fit(pandas.DataFrame(x_train['day_of_week']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['day_of_week']]=day_scaler.transform(x_train[['day_of_week']])

# %%
x_train.head()
# Out:
#             age       job  education   housing     month  day_of_week  \
# 8591   1.628822 -0.754524  -0.815072  0.940119 -0.098683     1.429890
# 24954  0.860477 -0.754524  -1.750565 -1.089425  1.195407     0.713608
# 39477  4.318032 -0.197733  -1.750565 -1.089425 -1.824138     0.713608
# 12427 -1.348516 -1.032919   1.055915  0.940119 -0.530047    -0.718956
# 14931  0.380261 -1.032919   1.055915 -1.089425 -0.530047     1.429890
#
#        duration     pdays   branchwise  cons.conf.idx   y
# 8591   0.412619  0.194661  nonexistent      -0.283170  no
# 24954 -0.863631  0.194661      failure      -0.326341  no
# 39477 -0.357730  0.194661  nonexistent       1.270978  no
# 12427 -0.541694  0.194661  nonexistent      -0.477439  no
# 14931 -0.261916  0.194661  nonexistent      -0.477439  no

# %%
branchwise_encoder=preprocessing.LabelEncoder()
branchwise_encoder.fit(pandas.DataFrame(x_train['branchwise']))
# Out:
# LabelEncoder()

# %%
x_train[['branchwise']]=branchwise_encoder.transform(x_train[['branchwise']])

# %%
x_train.head()
# Out:
#             age       job  education   housing     month  day_of_week  \
# 8591   1.628822 -0.754524  -0.815072  0.940119 -0.098683     1.429890
# 24954  0.860477 -0.754524  -1.750565 -1.089425  1.195407     0.713608
# 39477  4.318032 -0.197733  -1.750565 -1.089425 -1.824138     0.713608
# 12427 -1.348516 -1.032919   1.055915  0.940119 -0.530047    -0.718956
# 14931  0.380261 -1.032919   1.055915 -1.089425 -0.530047     1.429890
#
#        duration     pdays  branchwise  cons.conf.idx   y
# 8591   0.412619  0.194661           1      -0.283170  no
# 24954 -0.863631  0.194661           0      -0.326341  no
# 39477 -0.357730  0.194661           1       1.270978  no
# 12427 -0.541694  0.194661           1      -0.477439  no
# 14931 -0.261916  0.194661           1      -0.477439  no

# %%
branchwise_scaler=StandardScaler()
branchwise_scaler.fit(pandas.DataFrame(x_train['branchwise']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['branchwise']]=day_scaler.transform(x_train[['branchwise']])

# %%
x_train.head()
# Out:
#             age       job  education   housing     month  day_of_week  \
# 8591   1.628822 -0.754524  -0.815072  0.940119 -0.098683     1.429890
# 24954  0.860477 -0.754524  -1.750565 -1.089425  1.195407     0.713608
# 39477  4.318032 -0.197733  -1.750565 -1.089425 -1.824138     0.713608
# 12427 -1.348516 -1.032919   1.055915  0.940119 -0.530047    -0.718956
# 14931  0.380261 -1.032919   1.055915 -1.089425 -0.530047     1.429890
#
#        duration     pdays  branchwise  cons.conf.idx   y
# 8591   0.412619  0.194661   -0.718956      -0.283170  no
# 24954 -0.863631  0.194661   -1.435238      -0.326341  no
# 39477 -0.357730  0.194661   -0.718956       1.270978  no
# 12427 -0.541694  0.194661   -0.718956      -0.477439  no
# 14931 -0.261916  0.194661   -0.718956      -0.477439  no

# %%
x_train['y']=x_train['y'].map({'no':0,'yes':1})

# %%
x_train.head()
# Out:
#             age       job  education   housing     month  day_of_week  \
# 8591   1.628822 -0.754524  -0.815072  0.940119 -0.098683     1.429890
# 24954  0.860477 -0.754524  -1.750565 -1.089425  1.195407     0.713608
# 39477  4.318032 -0.197733  -1.750565 -1.089425 -1.824138     0.713608
# 12427 -1.348516 -1.032919   1.055915  0.940119 -0.530047    -0.718956
# 14931  0.380261 -1.032919   1.055915 -1.089425 -0.530047     1.429890
#
#        duration     pdays  branchwise  cons.conf.idx  y
# 8591   0.412619  0.194661   -0.718956      -0.283170  0
# 24954 -0.863631  0.194661   -1.435238      -0.326341  0
# 39477 -0.357730  0.194661   -0.718956       1.270978  0
# 12427 -0.541694  0.194661   -0.718956      -0.477439  0
# 14931 -0.261916  0.194661   -0.718956      -0.477439  0

# %%
x_train
# Out:
#             age       job  education   housing     month  day_of_week  \
# 8591   1.628822 -0.754524  -0.815072  0.940119 -0.098683     1.429890
# 24954  0.860477 -0.754524  -1.750565 -1.089425  1.195407     0.713608
# 39477  4.318032 -0.197733  -1.750565 -1.089425 -1.824138     0.713608
# 12427 -1.348516 -1.032919   1.055915  0.940119 -0.530047    -0.718956
# 14931  0.380261 -1.032919   1.055915 -1.089425 -0.530047     1.429890
# 18224 -0.388084  0.637454   1.055915 -1.089425 -0.530047     1.429890
# 19784 -0.964344 -1.032919   1.055915 -1.089425 -1.392774    -1.435238
# 24851 -0.292041  0.080663  -0.347325  0.940119  1.195407     0.713608
# 25024  0.092132  0.637454   1.055915 -1.089425  1.195407     0.713608
# 4961  -0.772257 -0.754524  -1.282819 -1.089425  0.764044     1.429890
# 2274  -0.964344 -1.032919  -0.347325 -1.089425  0.764044     0.713608
# 24274  0.956520 -1.032919   1.055915 -1.089425  1.195407    -0.718956
# ...

# %%
x_test
# Out:
#        age            job            education  housing month day_of_week  \
# 15570   33         admin.    university.degree       no   jul         fri
# 22930   45     management    university.degree       no   aug         mon
# 22249   47    blue-collar             basic.6y      yes   aug         thu
# 24987   49         admin.             basic.9y      yes   nov         tue
# 9966    25  self-employed  professional.course      yes   jun         wed
# 35372   54     management    university.degree       no   may         fri
# 20315   31     management    university.degree       no   aug         mon
# 18631   54    blue-collar             basic.9y      yes   jul         thu
# 40238   31        student    university.degree       no   jul         fri
# 14054   41         admin.    university.degree       no   jul         fri
# 26452   38  self-employed  professional.course      yes   nov         thu
# 9691    40    blue-collar             basic.6y       no   jun         mon
# ...

# %%
#checking the data
x_train_original=x_train
x_train=x_train.values
y_train=y_train.values

# %%
#applying the model
logistic_regression=LogisticRegression()

# %%
#fitting the data
logistic_regression.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
x_test
# Out:
#        age            job            education  housing month day_of_week  \
# 15570   33         admin.    university.degree       no   jul         fri
# 22930   45     management    university.degree       no   aug         mon
# 22249   47    blue-collar             basic.6y      yes   aug         thu
# 24987   49         admin.             basic.9y      yes   nov         tue
# 9966    25  self-employed  professional.course      yes   jun         wed
# 35372   54     management    university.degree       no   may         fri
# 20315   31     management    university.degree       no   aug         mon
# 18631   54    blue-collar             basic.9y      yes   jul         thu
# 40238   31        student    university.degree       no   jul         fri
# 14054   41         admin.    university.degree       no   jul         fri
# 26452   38  self-employed  professional.course      yes   nov         thu
# 9691    40    blue-collar             basic.6y       no   jun         mon
# ...

# %%
age_scaler=StandardScaler()
age_scaler.fit(pandas.DataFrame(x_test['age']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_test[['age']]=age_scaler.transform(x_test[['age']])

# %%
x_test.head()
# Out:
#             age            job            education housing month day_of_week  \
# 15570 -0.665312         admin.    university.degree      no   jul         fri
# 22930  0.482208     management    university.degree      no   aug         mon
# 22249  0.673461    blue-collar             basic.6y     yes   aug         thu
# 24987  0.864714         admin.             basic.9y     yes   nov         tue
# 9966  -1.430325  self-employed  professional.course     yes   jun         wed
#
#        duration  pdays   branchwise  cons.conf.idx   y
# 15570       305    999  nonexistent          -42.7  no
# 22930       105    999  nonexistent          -36.1  no
# 22249        43    999  nonexistent          -36.1  no
# 24987       204    999  nonexistent          -42.0  no
# 9966        394    999  nonexistent          -41.8  no

# %%
duration_scaler=StandardScaler()
duration_scaler.fit(pandas.DataFrame(x_test['duration']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_test[['duration']]=duration_scaler.transform(x_test[['duration']])

# %%
x_test.head()
# Out:
#             age            job            education housing month day_of_week  \
# 15570 -0.665312         admin.    university.degree      no   jul         fri
# 22930  0.482208     management    university.degree      no   aug         mon
# 22249  0.673461    blue-collar             basic.6y     yes   aug         thu
# 24987  0.864714         admin.             basic.9y     yes   nov         tue
# 9966  -1.430325  self-employed  professional.course     yes   jun         wed
#
#        duration  pdays   branchwise  cons.conf.idx   y
# 15570  0.201671    999  nonexistent          -42.7  no
# 22930 -0.590261    999  nonexistent          -36.1  no
# 22249 -0.835759    999  nonexistent          -36.1  no
# 24987 -0.198254    999  nonexistent          -42.0  no
# 9966   0.554081    999  nonexistent          -41.8  no

# %%
pdays_scaler=StandardScaler()
pdays_scaler.fit(pandas.DataFrame(x_test['pdays']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_test[['pdays']]=pdays_scaler.transform(x_test[['pdays']])

# %%
x_test.head()
# Out:
#             age            job            education housing month day_of_week  \
# 15570 -0.665312         admin.    university.degree      no   jul         fri
# 22930  0.482208     management    university.degree      no   aug         mon
# 22249  0.673461    blue-collar             basic.6y     yes   aug         thu
# 24987  0.864714         admin.             basic.9y     yes   nov         tue
# 9966  -1.430325  self-employed  professional.course     yes   jun         wed
#
#        duration     pdays   branchwise  cons.conf.idx   y
# 15570  0.201671  0.198402  nonexistent          -42.7  no
# 22930 -0.590261  0.198402  nonexistent          -36.1  no
# 22249 -0.835759  0.198402  nonexistent          -36.1  no
# 24987 -0.198254  0.198402  nonexistent          -42.0  no
# 9966   0.554081  0.198402  nonexistent          -41.8  no

# %%
cons_conf_idx_scaler=StandardScaler()
cons_conf_idx_scaler.fit(pandas.DataFrame(x_test['cons.conf.idx']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_test[['cons.conf.idx']]=cons_conf_idx_scaler.transform(x_test[['cons.conf.idx']])

# %%
x_test.head()
# Out:
#             age            job            education housing month day_of_week  \
# 15570 -0.665312         admin.    university.degree      no   jul         fri
# 22930  0.482208     management    university.degree      no   aug         mon
# 22249  0.673461    blue-collar             basic.6y     yes   aug         thu
# 24987  0.864714         admin.             basic.9y     yes   nov         tue
# 9966  -1.430325  self-employed  professional.course     yes   jun         wed
#
#        duration     pdays   branchwise  cons.conf.idx   y
# 15570  0.201671  0.198402  nonexistent      -0.464198  no
# 22930 -0.590261  0.198402  nonexistent       0.967734  no
# 22249 -0.835759  0.198402  nonexistent       0.967734  no
# 24987 -0.198254  0.198402  nonexistent      -0.312326  no
# 9966   0.554081  0.198402  nonexistent      -0.268934  no

# %%
job_encoder=preprocessing.LabelEncoder()
job_encoder.fit(pandas.DataFrame(x_test['job']))
# Out:
# LabelEncoder()

# %%
x_test[['job']]=job_encoder.transform(x_test[['job']])

# %%
x_test.head()
# Out:
#             age  job            education housing month day_of_week  duration  \
# 15570 -0.665312    0    university.degree      no   jul         fri  0.201671
# 22930  0.482208    4    university.degree      no   aug         mon -0.590261
# 22249  0.673461    1             basic.6y     yes   aug         thu -0.835759
# 24987  0.864714    0             basic.9y     yes   nov         tue -0.198254
# 9966  -1.430325    6  professional.course     yes   jun         wed  0.554081
#
#           pdays   branchwise  cons.conf.idx   y
# 15570  0.198402  nonexistent      -0.464198  no
# 22930  0.198402  nonexistent       0.967734  no
# 22249  0.198402  nonexistent       0.967734  no
# 24987  0.198402  nonexistent      -0.312326  no
# 9966   0.198402  nonexistent      -0.268934  no

# %%
job_scaler=StandardScaler()
job_scaler.fit(pandas.DataFrame(x_test['job']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_test[['job']]=job_scaler.transform(x_test[['job']])

# %%
x_test.head()
# Out:
#             age       job            education housing month day_of_week  \
# 15570 -0.665312 -1.049366    university.degree      no   jul         fri
# 22930  0.482208  0.060527    university.degree      no   aug         mon
# 22249  0.673461 -0.771893             basic.6y     yes   aug         thu
# 24987  0.864714 -1.049366             basic.9y     yes   nov         tue
# 9966  -1.430325  0.615473  professional.course     yes   jun         wed
#
#        duration     pdays   branchwise  cons.conf.idx   y
# 15570  0.201671  0.198402  nonexistent      -0.464198  no
# 22930 -0.590261  0.198402  nonexistent       0.967734  no
# 22249 -0.835759  0.198402  nonexistent       0.967734  no
# 24987 -0.198254  0.198402  nonexistent      -0.312326  no
# 9966   0.554081  0.198402  nonexistent      -0.268934  no

# %%
education_encoder=preprocessing.LabelEncoder()
education_encoder.fit(pandas.DataFrame(x_test['education']))
# Out:
# LabelEncoder()

# %%
x_test[['education']]=education_encoder.transform(x_test[['education']])

# %%
x_test.head()
# Out:
#             age       job  education housing month day_of_week  duration  \
# 15570 -0.665312 -1.049366          6      no   jul         fri  0.201671
# 22930  0.482208  0.060527          6      no   aug         mon -0.590261
# 22249  0.673461 -0.771893          1     yes   aug         thu -0.835759
# 24987  0.864714 -1.049366          2     yes   nov         tue -0.198254
# 9966  -1.430325  0.615473          5     yes   jun         wed  0.554081
#
#           pdays   branchwise  cons.conf.idx   y
# 15570  0.198402  nonexistent      -0.464198  no
# 22930  0.198402  nonexistent       0.967734  no
# 22249  0.198402  nonexistent       0.967734  no
# 24987  0.198402  nonexistent      -0.312326  no
# 9966   0.198402  nonexistent      -0.268934  no

# %%
education_scaler=StandardScaler()
education_scaler.fit(pandas.DataFrame(x_test['education']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_test[['education']]=education_scaler.transform(x_test[['education']])

# %%
x_test.head()
# Out:
#             age       job  education housing month day_of_week  duration  \
# 15570 -0.665312 -1.049366   1.048693      no   jul         fri  0.201671
# 22930  0.482208  0.060527   1.048693      no   aug         mon -0.590261
# 22249  0.673461 -0.771893  -1.298133     yes   aug         thu -0.835759
# 24987  0.864714 -1.049366  -0.828767     yes   nov         tue -0.198254
# 9966  -1.430325  0.615473   0.579328     yes   jun         wed  0.554081
#
#           pdays   branchwise  cons.conf.idx   y
# 15570  0.198402  nonexistent      -0.464198  no
# 22930  0.198402  nonexistent       0.967734  no
# 22249  0.198402  nonexistent       0.967734  no
# 24987  0.198402  nonexistent      -0.312326  no
# 9966   0.198402  nonexistent      -0.268934  no

# %%
housing_encoder=preprocessing.LabelEncoder()
housing_encoder.fit(pandas.DataFrame(x_test['housing']))
# Out:
# LabelEncoder()

# %%
x_test[['housing']]=housing_encoder.transform(x_test[['housing']])

# %%
x_test.head()
# Out:
#             age       job  education  housing month day_of_week  duration  \
# 15570 -0.665312 -1.049366   1.048693        0   jul         fri  0.201671
# 22930  0.482208  0.060527   1.048693        0   aug         mon -0.590261
# 22249  0.673461 -0.771893  -1.298133        2   aug         thu -0.835759
# 24987  0.864714 -1.049366  -0.828767        2   nov         tue -0.198254
# 9966  -1.430325  0.615473   0.579328        2   jun         wed  0.554081
#
#           pdays   branchwise  cons.conf.idx   y
# 15570  0.198402  nonexistent      -0.464198  no
# 22930  0.198402  nonexistent       0.967734  no
# 22249  0.198402  nonexistent       0.967734  no
# 24987  0.198402  nonexistent      -0.312326  no
# 9966   0.198402  nonexistent      -0.268934  no

# %%
housing_scaler=StandardScaler()
housing_scaler.fit(pandas.DataFrame(x_test['housing']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_test[['housing']]=housing_scaler.transform(x_test[['housing']])

# %%
x_test.head()
# Out:
#             age       job  education   housing month day_of_week  duration  \
# 15570 -0.665312 -1.049366   1.048693 -1.080870   jul         fri  0.201671
# 22930  0.482208  0.060527   1.048693 -1.080870   aug         mon -0.590261
# 22249  0.673461 -0.771893  -1.298133  0.950199   aug         thu -0.835759
# 24987  0.864714 -1.049366  -0.828767  0.950199   nov         tue -0.198254
# 9966  -1.430325  0.615473   0.579328  0.950199   jun         wed  0.554081
#
#           pdays   branchwise  cons.conf.idx   y
# 15570  0.198402  nonexistent      -0.464198  no
# 22930  0.198402  nonexistent       0.967734  no
# 22249  0.198402  nonexistent       0.967734  no
# 24987  0.198402  nonexistent      -0.312326  no
# 9966   0.198402  nonexistent      -0.268934  no

# %%
month_encoder=preprocessing.LabelEncoder()
month_encoder.fit(pandas.DataFrame(x_test['month']))
# Out:
# LabelEncoder()

# %%
x_test[['month']]=month_encoder.transform(x_test[['month']])

# %%
x_test.head()
# Out:
#             age       job  education   housing  month day_of_week  duration  \
# 15570 -0.665312 -1.049366   1.048693 -1.080870      3         fri  0.201671
# 22930  0.482208  0.060527   1.048693 -1.080870      1         mon -0.590261
# 22249  0.673461 -0.771893  -1.298133  0.950199      1         thu -0.835759
# 24987  0.864714 -1.049366  -0.828767  0.950199      7         tue -0.198254
# 9966  -1.430325  0.615473   0.579328  0.950199      4         wed  0.554081
#
#           pdays   branchwise  cons.conf.idx   y
# 15570  0.198402  nonexistent      -0.464198  no
# 22930  0.198402  nonexistent       0.967734  no
# 22249  0.198402  nonexistent       0.967734  no
# 24987  0.198402  nonexistent      -0.312326  no
# 9966   0.198402  nonexistent      -0.268934  no

# %%
month_scaler=StandardScaler()
month_scaler.fit(pandas.DataFrame(x_test['month']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_test[['month']]=month_scaler.transform(x_test[['month']])

# %%
x_test.head()
# Out:
#             age       job  education   housing     month day_of_week  \
# 15570 -0.665312 -1.049366   1.048693 -1.080870 -0.532548         fri
# 22930  0.482208  0.060527   1.048693 -1.080870 -1.392012         mon
# 22249  0.673461 -0.771893  -1.298133  0.950199 -1.392012         thu
# 24987  0.864714 -1.049366  -0.828767  0.950199  1.186379         tue
# 9966  -1.430325  0.615473   0.579328  0.950199 -0.102816         wed
#
#        duration     pdays   branchwise  cons.conf.idx   y
# 15570  0.201671  0.198402  nonexistent      -0.464198  no
# 22930 -0.590261  0.198402  nonexistent       0.967734  no
# 22249 -0.835759  0.198402  nonexistent       0.967734  no
# 24987 -0.198254  0.198402  nonexistent      -0.312326  no
# 9966   0.554081  0.198402  nonexistent      -0.268934  no

# %%
day_encoder=preprocessing.LabelEncoder()
day_encoder.fit(pandas.DataFrame(x_test['day_of_week']))
# Out:
# LabelEncoder()

# %%
x_test[['day_of_week']]=day_encoder.transform(x_test[['day_of_week']])

# %%
x_test.head()
# Out:
#             age       job  education   housing     month  day_of_week  \
# 15570 -0.665312 -1.049366   1.048693 -1.080870 -0.532548            0
# 22930  0.482208  0.060527   1.048693 -1.080870 -1.392012            1
# 22249  0.673461 -0.771893  -1.298133  0.950199 -1.392012            2
# 24987  0.864714 -1.049366  -0.828767  0.950199  1.186379            3
# 9966  -1.430325  0.615473   0.579328  0.950199 -0.102816            4
#
#        duration     pdays   branchwise  cons.conf.idx   y
# 15570  0.201671  0.198402  nonexistent      -0.464198  no
# 22930 -0.590261  0.198402  nonexistent       0.967734  no
# 22249 -0.835759  0.198402  nonexistent       0.967734  no
# 24987 -0.198254  0.198402  nonexistent      -0.312326  no
# 9966   0.554081  0.198402  nonexistent      -0.268934  no

# %%
branchwise_encoder=preprocessing.LabelEncoder()
branchwise_encoder.fit(pandas.DataFrame(x_test['branchwise']))
# Out:
# LabelEncoder()

# %%
x_test[['branchwise']]=branchwise_encoder.transform(x_test[['branchwise']])

# %%
x_test.head()
# Out:
#             age       job  education   housing     month  day_of_week  \
# 15570 -0.665312 -1.049366   1.048693 -1.080870 -0.532548            0
# 22930  0.482208  0.060527   1.048693 -1.080870 -1.392012            1
# 22249  0.673461 -0.771893  -1.298133  0.950199 -1.392012            2
# 24987  0.864714 -1.049366  -0.828767  0.950199  1.186379            3
# 9966  -1.430325  0.615473   0.579328  0.950199 -0.102816            4
#
#        duration     pdays  branchwise  cons.conf.idx   y
# 15570  0.201671  0.198402           1      -0.464198  no
# 22930 -0.590261  0.198402           1       0.967734  no
# 22249 -0.835759  0.198402           1       0.967734  no
# 24987 -0.198254  0.198402           1      -0.312326  no
# 9966   0.554081  0.198402           1      -0.268934  no

# %%
branchwise_scaler=StandardScaler()
branchwise_scaler.fit(pandas.DataFrame(x_test['branchwise']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_test[['branchwise']]=branchwise_scaler.transform(x_test[['branchwise']])

# %%
x_test.head()
# Out:
#             age       job  education   housing     month  day_of_week  \
# 15570 -0.665312 -1.049366   1.048693 -1.080870 -0.532548            0
# 22930  0.482208  0.060527   1.048693 -1.080870 -1.392012            1
# 22249  0.673461 -0.771893  -1.298133  0.950199 -1.392012            2
# 24987  0.864714 -1.049366  -0.828767  0.950199  1.186379            3
# 9966  -1.430325  0.615473   0.579328  0.950199 -0.102816            4
#
#        duration     pdays  branchwise  cons.conf.idx   y
# 15570  0.201671  0.198402    0.195643      -0.464198  no
# 22930 -0.590261  0.198402    0.195643       0.967734  no
# 22249 -0.835759  0.198402    0.195643       0.967734  no
# 24987 -0.198254  0.198402    0.195643      -0.312326  no
# 9966   0.554081  0.198402    0.195643      -0.268934  no

# %%
day_scaler=StandardScaler()
day_scaler.fit(pandas.DataFrame(x_test['day_of_week']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_test[['day_of_week']]=day_scaler.transform(x_test[['day_of_week']])

# %%
x_test.head()
# Out:
#             age       job  education   housing     month  day_of_week  \
# 15570 -0.665312 -1.049366   1.048693 -1.080870 -0.532548    -1.430930
# 22930  0.482208  0.060527   1.048693 -1.080870 -1.392012    -0.718363
# 22249  0.673461 -0.771893  -1.298133  0.950199 -1.392012    -0.005795
# 24987  0.864714 -1.049366  -0.828767  0.950199  1.186379     0.706772
# 9966  -1.430325  0.615473   0.579328  0.950199 -0.102816     1.419339
#
#        duration     pdays  branchwise  cons.conf.idx   y
# 15570  0.201671  0.198402    0.195643      -0.464198  no
# 22930 -0.590261  0.198402    0.195643       0.967734  no
# 22249 -0.835759  0.198402    0.195643       0.967734  no
# 24987 -0.198254  0.198402    0.195643      -0.312326  no
# 9966   0.554081  0.198402    0.195643      -0.268934  no

# %%
x_test['y']=x_test['y'].map({'no':0,'yes':1})

# %%
x_test.head()
# Out:
#             age       job  education   housing     month  day_of_week  \
# 15570 -0.665312 -1.049366   1.048693 -1.080870 -0.532548    -1.430930
# 22930  0.482208  0.060527   1.048693 -1.080870 -1.392012    -0.718363
# 22249  0.673461 -0.771893  -1.298133  0.950199 -1.392012    -0.005795
# 24987  0.864714 -1.049366  -0.828767  0.950199  1.186379     0.706772
# 9966  -1.430325  0.615473   0.579328  0.950199 -0.102816     1.419339
#
#        duration     pdays  branchwise  cons.conf.idx  y
# 15570  0.201671  0.198402    0.195643      -0.464198  0
# 22930 -0.590261  0.198402    0.195643       0.967734  0
# 22249 -0.835759  0.198402    0.195643       0.967734  0
# 24987 -0.198254  0.198402    0.195643      -0.312326  0
# 9966   0.554081  0.198402    0.195643      -0.268934  0

# %%
#predicting the model
y_pred=logistic_regression.predict(x_test)

# %%
#printing the accuracy
print(accuracy_score(y_test,y_pred))
# Out:
# 0.820830298616169
